# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
data= pd.read_csv('diabetes.csv')
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import numpy as np

corr_matrix = data.corr()

plt.figure(figsize=(10, 8))

plt.imshow(corr_matrix, cmap='PuBu', interpolation='nearest')
plt.colorbar()

for i in range(len(corr_matrix)):
    for j in range(len(corr_matrix.columns)):
        plt.text(j, i, f"{corr_matrix.iloc[i, j]:.3f}", ha='center', va='center', color='red')

plt.xticks(np.arange(len(corr_matrix.columns)), corr_matrix.columns, rotation=90)
plt.yticks(np.arange(len(corr_matrix.index)), corr_matrix.index)

plt.title("Correlation Heatmap")
plt.show()

# %%
import matplotlib.pyplot as plt


plt.figure(figsize=(10, 8))


plt.hist(data["Pregnancies"][data['Outcome'] == 1], bins=30, color='green', alpha=0.5, density=True, label='Positive')
plt.hist(data["Pregnancies"][data['Outcome'] == 0], bins=30, color='blue', alpha=0.5, density=True, label='Negative')

plt.xlabel('Pregnancies')
plt.ylabel('Density')

plt.legend()

plt.show()

# %%
plt.figure(figsize=(10,8))
kde= sns.kdeplot(data["Pregnancies"][data['Outcome']==1],color='green',shade=True)
kde= sns.kdeplot(data["Pregnancies"][data['Outcome']==0],color='blue',shade=True)
kde.set_xlabel('preganancies')
kde.set_ylabel('Density')
kde.legend(['positive','negative'])
# Out:
# C:\Users\mydhi\AppData\Local\Temp\ipykernel_13584\1249147091.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   kde= sns.kdeplot(data["Pregnancies"][data['Outcome']==1],color='green',shade=True)
# C:\Users\mydhi\AppData\Local\Temp\ipykernel_13584\1249147091.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   kde= sns.kdeplot(data["Pregnancies"][data['Outcome']==0],color='blue',shade=True)

# %%
import matplotlib.pyplot as plt


data_positive = data["Pregnancies"][data['Outcome'] == 1]
data_negative = data["Pregnancies"][data['Outcome'] == 0]


data_combined = [data_positive, data_negative]


plt.figure(figsize=(10, 8))
plt.violinplot(data_combined, showmeans=True, showmedians=True)

plt.xticks([1, 2], ['Positive', 'Negative'])

plt.xlabel('Outcome')
plt.ylabel('Pregnancies')

plt.title('Violin Plot of Pregnancies by Outcome')

plt.show()

# %%
data['Glucose']=data['Glucose'].replace(0,data['Glucose'].median())
data['BloodPressure']=data['BloodPressure'].replace(0,data['BloodPressure'].median())
data['SkinThickness']=data['SkinThickness'].replace(0,data['SkinThickness'].median())
data['Insulin']=data['Insulin'].replace(0,data['Insulin'].median())
data['BMI']=data['BMI'].replace(0,data['BMI'].median())

# %%
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35     30.5  33.6
# 1              1       85             66             29     30.5  26.6
# 2              8      183             64             23     30.5  23.3
# 3              1       89             66             23     94.0  28.1
# 4              0      137             40             35    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48    180.0  32.9
# 764            2      122             70             27     30.5  36.8
# 765            5      121             72             23    112.0  26.2
# 766            1      126             60             23     30.5  30.1
# 767            1       93             70             31     30.5  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
x=data.drop(['Outcome'],axis=1)
y=data['Outcome']

# %%
x
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35     30.5  33.6
# 1              1       85             66             29     30.5  26.6
# 2              8      183             64             23     30.5  23.3
# 3              1       89             66             23     94.0  28.1
# 4              0      137             40             35    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48    180.0  32.9
# 764            2      122             70             27     30.5  36.8
# 765            5      121             72             23    112.0  26.2
# 766            1      126             60             23     30.5  30.1
# 767            1       93             70             31     30.5  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)
x_train
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 464           10      115             98             23     30.5  24.0
# 223            7      142             60             33    190.0  28.8
# 393            4      116             72             12     87.0  22.1
# 766            1      126             60             23     30.5  30.1
# 570            3       78             70             23     30.5  32.5
# ..           ...      ...            ...            ...      ...   ...
# 71             5      139             64             35    140.0  28.6
# 106            1       96            122             23     30.5  22.4
# 270           10      101             86             37     30.5  45.6
# 435            0      141             72             23     30.5  42.4
# 102            0      125             96             23     30.5  22.5
#
#      DiabetesPedigreeFunction  Age
# 464                     1.022   34
# 223                     0.687   61
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
test_accuracy=[]
training_accuracy=[]
for n_neighbors in range(1, 11):
    knn = KNeighborsClassifier(n_neighbors=n_neighbors)
    knn.fit(x_train, y_train)
    training_accuracy.append(knn.score(x_train, y_train))
    test_accuracy.append(knn.score(x_test, y_test))

# %%
plt.plot(range(1, 11), training_accuracy, color='r',label="training_accuracy")
plt.plot(range(1, 11), test_accuracy,color='y', label="test_accuracy")
plt.ylabel("Accuracy")
plt.xlabel("n_neighbors")
plt.legend()

# %%
from sklearn.neighbors import KNeighborsClassifier

model = KNeighborsClassifier(n_neighbors=9)
model.fit(x_train, y_train)

training_accuracy = model.score(x_train, y_train)
print(f"Training accuracy: {training_accuracy}")

test_accuracy = model.score(x_test, y_test)
print(f"Test accuracy: {test_accuracy}")
# Out:
# Training accuracy: 0.7898832684824902
# Test accuracy: 0.7322834645669292

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(random_state=0)
dt.fit(x_train, y_train)
print(dt.score(x_train, y_train), ": Training accuracy")
print(dt.score(x_test, y_test), ": Test accuracy")
# Out:
# 1.0 : Training accuracy
# 0.6929133858267716 : Test accuracy

# %%
from sklearn.tree import DecisionTreeClassifier

tree_model = DecisionTreeClassifier(random_state=0, max_depth=6)
tree_model.fit(x_train, y_train)

train_accuracy = tree_model.score(x_train, y_train)
print(f"Training accuracy: {train_accuracy}")

test_accuracy = tree_model.score(x_test, y_test)
print(f"Test accuracy: {test_accuracy}")
# Out:
# Training accuracy: 0.857976653696498
# Test accuracy: 0.7362204724409449

# %%
from sklearn.neural_network import MLPClassifier

mlp_model = MLPClassifier(random_state=42)
mlp_model.fit(x_train, y_train)

training_accuracy = mlp_model.score(x_train, y_train)
print(f"Training accuracy: {training_accuracy}")

test_accuracy = mlp_model.score(x_test, y_test)
print(f"Test accuracy: {test_accuracy}")
# Out:
# Training accuracy: 0.7645914396887159
# Test accuracy: 0.7047244094488189

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

mlp_model = MLPClassifier(random_state=0)
mlp_model.fit(x_train_scaled, y_train)

train_accuracy = mlp_model.score(X_train_scaled, y_train)
print(f"Training accuracy: {train_accuracy}")

test_accuracy = mlp_model.score(X_test_scaled, y_test)
print(f"Test accuracy: {test_accuracy}")
# Out:
# Training accuracy: 0.8365758754863813
# Test accuracy: 0.7480314960629921
# C:\Users\mydhi\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
