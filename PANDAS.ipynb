# %%
import pandas as pd

# %%
df=pd.read_csv('2019_stack_results.csv')

# %%
df['Hobbyist'].value_counts()
# Out:
# Hobbyist
# Yes    71257
# No     17626
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (88883, 85)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88883 entries, 0 to 88882
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              88883 non-null  int64
#  1   MainBranch              88331 non-null  object
#  2   Hobbyist                88883 non-null  object
#  3   OpenSourcer             88883 non-null  object
#  4   OpenSource              86842 non-null  object
#  5   Employment              87181 non-null  object
#  6   Country                 88751 non-null  object
#  7   Student                 87014 non-null  object
#  8   EdLevel                 86390 non-null  object
#  9   UndergradMajor          75614 non-null  object
#  10  EduOther                84260 non-null  object
#  11  OrgSize                 71791 non-null  object
#  12  DevType                 81335 non-null  object
#  13  YearsCode               87938 non-null  object
# ...

# %%
pd.set_option('display.max_columns',85)
pd.set_option('display.max_rows',85)

# %% [markdown]
# df2=pd.read_csv('2019_survey_schema.csv')

# %%
df2=pd.read_csv('2019_survey_schema.csv')

# %%
df2.sort_index()
# Out:
#                     Column                                       QuestionText
# 0               Respondent  Randomized respondent ID number (not in order ...
# 1               MainBranch  Which of the following options best describes ...
# 2                 Hobbyist                            Do you code as a hobby?
# 3              OpenSourcer        How often do you contribute to open source?
# 4               OpenSource  How do you feel about the quality of open sour...
# 5               Employment  Which of the following best describes your cur...
# 6                  Country          In which country do you currently reside?
# 7                  Student  Are you currently enrolled in a formal, degree...
# 8                  EdLevel  Which of the following best describes the high...
# 9           UndergradMajor  What was your main or most important field of ...
# 10                EduOther  Which of the following types of non-degree edu...
# ...

# %%
per1={'first':'cherry','last':'berry'}
per2={'first':'sonu','last':'bunty'}

# %%
people={'first':['cherry','sonu'],
         'last':['berry','bunty']}

# %%
import pandas as pd

# %%
df=pd.DataFrame(people)

# %%
df.iloc[[1,0],[0,1]]
# Out:
#     first   last
# 1    sonu  bunty
# 0  cherry  berry

# %%
df.iloc[0:2,2:6]
# Out:
#   Hobbyist              OpenSourcer  \
# 0      Yes                    Never
# 1       No  Less than once per year
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
#
#                                Employment
# 0  Not employed, and not looking for work
# 1      Not employed, but looking for work

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
df.loc[df['ConvertedComp']>70000,['ConvertedComp','LanguageWorkedWith','Country']]
# Out:
#        ConvertedComp                                 LanguageWorkedWith  \
# 5           366420.0                                         Java;R;SQL
# 8            95179.0  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 12           90000.0  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 15          455352.0  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# 21          103000.0  Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# ...              ...                                                ...
# 88323       180000.0  Bash/Shell/PowerShell;C#;HTML/CSS;Java;Python;...
# 88324      2000000.0  Bash/Shell/PowerShell;C;Clojure;HTML/CSS;Java;...
# 88325       130000.0               HTML/CSS;JavaScript;Scala;TypeScript
# 88326        82488.0                   Bash/Shell/PowerShell;C++;Python
# 88329       588012.0             C#;HTML/CSS;Java;JavaScript;PHP;Python
#
#               Country
# 5              Canada
# 8         New Zealand
# 12      United States
# ...

# %%
high_salries=df['ConvertedComp']>70000

# %%
pd.set_option('display.max_columns',85)
pd.set_option('display.max_rows',85)

# %%
countries=['Unites States','India','United Kingdom','Germany','Canada']
filt=df['Country'].isin(countries)
lict=df['ConvertedComp']>70000

# %%
df.loc[filt,'Country']
# Out:
# 0        United Kingdom
# 5                Canada
# 7                 India
# 9                 India
# 11               Canada
#               ...
# 88854    United Kingdom
# 88855            Canada
# 88863    United Kingdom
# 88864             India
# 88878            Canada
# Name: Country, Length: 24059, dtype: object

# %%
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 5               6  I am not primarily a developer, but I write co...      Yes
# 8               9                     I am a developer by profession      Yes
# 12             13                     I am a developer by profession      Yes
# 15             16                     I am a developer by profession      Yes
# 21             22                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88323       88876                     I am a developer by profession      Yes
# 88324       88877                     I am a developer by profession      Yes
# 88325       88878                     I am a developer by profession      Yes
# 88326       88879                     I am a developer by profession      Yes
# 88329       88882                     I am a developer by profession      Yes
#
# ...

# %%
df[filt]
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 5               6  I am not primarily a developer, but I write co...      Yes
# 7               8                        I code primarily as a hobby      Yes
# 9              10                     I am a developer by profession      Yes
# 11             12             I am a student who is learning to code       No
# ...           ...                                                ...      ...
# 88854       84539                                                NaN      Yes
# 88855       85182                                                NaN       No
# 88863       85961                                                NaN      Yes
# 88864       86012                                                NaN      Yes
# 88878       88377                                                NaN      Yes
#
# ...

# %%
filt=df['LanguageWorkedWith'].str.contains('Python',na=False)

# %%
df.loc[filt,'LanguageWorkedWith']
# Out:
# 0                          HTML/CSS;Java;JavaScript;Python
# 1                                      C++;HTML/CSS;Python
# 3                                      C;C++;C#;Python;SQL
# 4              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 7        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 88854    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 88860      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 88865      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 88872             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88876                           HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: object

# %%
df.rename(columns={'ConvertedComp':'SalaryUSD'})
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
df['Hobbyist']=df['Hobbyist'].replace({'Yes': True})

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code     True
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...     True
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession     True
# ...           ...                                                ...      ...
# 88878       88377                                                NaN     True
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN     True
#
# ...

# %%
df['ConvertedComp'].median()
# Out:
# 57287.0

# %%
df.describe()
# Out:
#          Respondent     CompTotal  ConvertedComp   WorkWeekHrs    CodeRevHrs  \
# count  88883.000000  5.594500e+04   5.582300e+04  64503.000000  49790.000000
# mean   44442.000000  5.519014e+11   1.271107e+05     42.127197      5.084308
# std    25658.456325  7.331926e+13   2.841523e+05     37.287610      5.513931
# min        1.000000  0.000000e+00   0.000000e+00      1.000000      0.000000
# 25%    22221.500000  2.000000e+04   2.577750e+04     40.000000      2.000000
# 50%    44442.000000  6.200000e+04   5.728700e+04     40.000000      4.000000
# 75%    66662.500000  1.200000e+05   1.000000e+05     44.750000      6.000000
# max    88883.000000  1.000000e+16   2.000000e+06   4850.000000     99.000000
#
#                 Age
# count  79210.000000
# mean      30.336699
# std        9.178390
# min        1.000000
# 25%       24.000000
# 50%       29.000000
# 75%       35.000000
# max       99.000000

# %%
df['ConvertedComp'].count()
# Out:
# 55823

# %%
df['OpenSourcer'].value_counts()
# Out:
# OpenSourcer
# Never                                                 32295
# Less than once per year                               24972
# Less than once a month but more than once per year    20561
# Once a month or more often                            11055
# Name: count, dtype: int64

# %%
df['SocialMedia'].value_counts(normalize=True)
# Out:
# SocialMedia
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: proportion, dtype: float64

# %%
df['Country'].value_counts()
# Out:
# Country
# United States        20949
# India                 9061
# Germany               5866
# United Kingdom        5737
# Canada                3395
#                      ...
# Tonga                    1
# Timor-Leste              1
# North Korea              1
# Brunei Darussalam        1
# Chad                     1
# Name: count, Length: 179, dtype: int64

# %%
country_grp=df.groupby(['Country'])

# %%
country_grp.get_group('India')
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 7               8             I code primarily as a hobby     True
# 9              10          I am a developer by profession     True
# 14             15  I am a student who is learning to code     True
# 49             50          I am a developer by profession     True
# 64             65          I am a developer by profession     True
# ...           ...                                     ...      ...
# 88808       77339                                     NaN     True
# 88825       79795                                     NaN     True
# 88852       83862                                     NaN     True
# 88853       84299                                     NaN     True
# 88864       86012                                     NaN     True
#
#                                              OpenSourcer  \
# 7                                Less than once per year
# ...

# %%
filt=(df['Country']=='India')
df.loc[filt,'SocialMedia'].value_counts()
# Out:
# SocialMedia
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# Hello                          5
# WeChat 微信                      5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# Name: count, dtype: int64

# %%
country_grp['SocialMedia'].value_counts(normalize=True).loc['United States']
# Out:
# SocialMedia
# Reddit                      0.284346
# Twitter                     0.173002
# Facebook                    0.141874
# YouTube                     0.122867
# I don't use social media    0.092338
# Instagram                   0.082410
# LinkedIn                    0.050883
# WhatsApp                    0.030380
# Snapchat                    0.016263
# WeChat 微信                   0.004639
# VK ВКонта́кте               0.000449
# Weibo 新浪微博                  0.000399
# Hello                       0.000100
# Youku Tudou 优酷              0.000050
# Name: proportion, dtype: float64

# %%
country_grp['ConvertedComp'].median().loc['Germany']
# Out:
# 63016.0

# %%
country_grp['ConvertedComp'].agg(['median','mean']).loc['Germany']
# Out:
# median     63016.000000
# mean      109256.884066
# Name: Germany, dtype: float64

# %%
filt=(df['Country']=='India')
df.loc[filt,'LanguageWorkedWith'].str.contains('Python').value_counts()
# Out:
# LanguageWorkedWith
# False    5739
# True     3105
# Name: count, dtype: int64

# %%
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').value_counts(normalize=True))
# Out:
# Country
# Afghanistan  False    0.794872
#              True     0.205128
# Albania      False    0.722892
#              True     0.277108
# Algeria      False    0.682540
#                         ...
# Yemen        True     0.176471
# Zambia       False    0.666667
#              True     0.333333
# Zimbabwe     False    0.641026
#              True     0.358974
# Name: LanguageWorkedWith, Length: 335, dtype: float64

# %%
df1=df['Country'].value_counts()
df2=country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
mnk=pd.concat([df1,df2],axis='columns')

# %% [markdown]
# mnk

# %%
mnk
# Out:
#                    count  LanguageWorkedWith
# Country
# United States      20949               10083
# India               9061                3105
# Germany             5866                2451
# United Kingdom      5737                2384
# Canada              3395                1558
# ...                  ...                 ...
# Tonga                  1                   0
# Timor-Leste            1                   1
# North Korea            1                   0
# Brunei Darussalam      1                   0
# Chad                   1                   0
#
# [179 rows x 2 columns]

# %%
mnk['pctpyknows']=mnk['LanguageWorkedWith']/mnk['count']*100

# %%
mnk
# Out:
#                    count  LanguageWorkedWith  pctpyknows
# Country
# United States      20949               10083   48.131176
# India               9061                3105   34.267741
# Germany             5866                2451   41.783157
# United Kingdom      5737                2384   41.554820
# Canada              3395                1558   45.891016
# ...                  ...                 ...         ...
# Tonga                  1                   0    0.000000
# Timor-Leste            1                   1  100.000000
# North Korea            1                   0    0.000000
# Brunei Darussalam      1                   0    0.000000
# Chad                   1                   0    0.000000
#
# [179 rows x 3 columns]

# %%
mnk.sort_values(by='pctpyknows',ascending=False)
# Out:
#                                   count  LanguageWorkedWith  pctpyknows
# Country
# Sao Tome and Principe                 1                   1  100.000000
# Timor-Leste                           1                   1  100.000000
# Dominica                              1                   1  100.000000
# Niger                                 1                   1  100.000000
# Turkmenistan                          7                   6   85.714286
# ...                                 ...                 ...         ...
# Cape Verde                            3                   0    0.000000
# Lao People's Democratic Republic      3                   0    0.000000
# Malawi                                2                   0    0.000000
# Liberia                               2                   0    0.000000
# Chad                                  1                   0    0.000000
#
# [179 rows x 3 columns]

# %%
mnk.loc['India']
# Out:
# count                 9061.000000
# LanguageWorkedWith    3105.000000
# pctpyknows              34.267741
# Name: India, dtype: float64

# %%
df.dtypes
# Out:
# Respondent       int64
# MainBranch      object
# Hobbyist        object
# OpenSourcer     object
# OpenSource      object
#                  ...
# Sexuality       object
# Ethnicity       object
# Dependents      object
# SurveyLength    object
# SurveyEase      object
# Length: 85, dtype: object

# %%
df['YearsCode'].unique()
# Out:
# array(['4', nan, '3', '16', '13', '6', '8', '12', '2', '5', '17', '10',
#        '14', '35', '7', 'Less than 1 year', '30', '9', '26', '40', '19',
#        '15', '20', '28', '25', '1', '22', '11', '33', '50', '41', '18',
#        '34', '24', '23', '42', '27', '21', '36', '32', '39', '38', '31',
#        '37', 'More than 50 years', '29', '44', '45', '48', '46', '43',
#        '47', '49'], dtype=object)

# %%
df['YearsCode']=df['YearsCode'].astype(float)

# %%
df['YearsCode'].replace('Less than 1 year',0,inplace=True)
df['YearsCode'].replace('More than 50 years',51,inplace=True)

# %%
df['YearsCode'].median()
# Out:
# 9.0

# %%
df=pd.read_csv('timeseriespd.csv')

# %%
df
# Out:
#                    Date  Symbol    Open    High     Low   Close      Volume
# 0      2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1      2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2      2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3      2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4      2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                 ...     ...     ...     ...     ...     ...         ...
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
df['Date']=pd.to_datetime(df['Date'],format='%Y-%m-%d %I-%p')

# %%
df['Date']
# Out:
# 0       2020-03-13 20:00:00
# 1       2020-03-13 19:00:00
# 2       2020-03-13 18:00:00
# 3       2020-03-13 17:00:00
# 4       2020-03-13 16:00:00
#                 ...
# 23669   2017-07-01 15:00:00
# 23670   2017-07-01 14:00:00
# 23671   2017-07-01 13:00:00
# 23672   2017-07-01 12:00:00
# 23673   2017-07-01 11:00:00
# Name: Date, Length: 23674, dtype: datetime64[ns]

# %%
df
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
df.loc[1,'Date'].day_name()
# Out:
# 'Friday'

# %%
df['Date'].dt.day_name()
# Out:
# 0          Friday
# 1          Friday
# 2          Friday
# 3          Friday
# 4          Friday
#            ...
# 23669    Saturday
# 23670    Saturday
# 23671    Saturday
# 23672    Saturday
# 23673    Saturday
# Name: Date, Length: 23674, dtype: object

# %%
df['Date'].min()-df['Date'].max()
# Out:
# Timedelta('-987 days +15:00:00')

# %%
filt=df['Date']>'2019'
df.loc[filt]
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 10503 2019-01-01 05:00:00  ETHUSD  131.96  132.58  131.96  132.48   317851.90
# 10504 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 10505 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 10506 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 10507 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
#
# [10508 rows x 7 columns]

# %%
filt=df['Date']>pd.to_datetime('2020-01')
df.loc[filt]
# Out:
#                     Date  Symbol    Open    High     Low   Close      Volume
# 0    2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1    2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2    2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3    2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4    2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                  ...     ...     ...     ...     ...     ...         ...
# 1743 2020-01-01 05:00:00  ETHUSD  129.56  129.94  129.47  129.83   232163.70
# 1744 2020-01-01 04:00:00  ETHUSD  129.57  130.00  129.50  129.56   702786.82
# 1745 2020-01-01 03:00:00  ETHUSD  130.37  130.44  129.38  129.57   496704.23
# 1746 2020-01-01 02:00:00  ETHUSD  130.14  130.50  129.91  130.37   396315.72
# 1747 2020-01-01 01:00:00  ETHUSD  128.34  130.14  128.32  130.14   635419.40
#
# [1748 rows x 7 columns]

# %%
####instead of applying filters we can use slicing

# %%
df.set_index('Date',inplace=True)

# %%
df
# Out:
#                      Symbol    Open    High     Low   Close      Volume
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                     ...     ...     ...     ...     ...         ...
# 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 6 columns]

# %%
df['2019']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2019'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 1
# ...

# %%
df['2020-01':'2020-02']
# Out:
#                      Symbol    Open    High     Low   Close      Volume
# Date
# 2020-02-29 23:00:00  ETHUSD  223.35  223.58  216.83  217.31  1927939.88
# 2020-02-29 22:00:00  ETHUSD  223.48  223.59  222.14  223.35   535998.57
# 2020-02-29 21:00:00  ETHUSD  224.63  225.14  222.74  223.48   561158.03
# 2020-02-29 20:00:00  ETHUSD  225.31  225.33  223.50  224.63   511648.65
# 2020-02-29 19:00:00  ETHUSD  225.09  225.85  223.87  225.31  1250856.20
# ...                     ...     ...     ...     ...     ...         ...
# 2020-01-01 04:00:00  ETHUSD  129.57  130.00  129.50  129.56   702786.82
# 2020-01-01 03:00:00  ETHUSD  130.37  130.44  129.38  129.57   496704.23
# 2020-01-01 02:00:00  ETHUSD  130.14  130.50  129.91  130.37   396315.72
# 2020-01-01 01:00:00  ETHUSD  128.34  130.14  128.32  130.14   635419.40
# 2020-01-01 00:00:00  ETHUSD  128.54  128.54  128.12  128.34   245119.91
#
# [1440 rows x 6 columns]

# %%
df['2020-01':'2020-02']['High'].max()
# Out:
# 290.0

# %%
highs=df['High'].resample('M').max()
highs['2020-01':'2020-02']
# Out:
# Date
# 2020-01-31    186.89
# 2020-02-29    290.00
# Freq: M, Name: High, dtype: float64

# %%
df['2020-01-02']['High'].max()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2020-01-02'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
highs=df['High'].resample('D').max()
highs['2020-01':'2020-02']
import matplotlib
highs.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df.resample('W').agg({'High':'mean','Close':'max','Low':'min','Volume':'sum'})
# Out:
#                   High   Close     Low        Volume
# Date
# 2017-07-02  271.124595  292.54  253.23  8.084631e+07
# 2017-07-09  262.872917  282.58  231.25  2.246746e+08
# 2017-07-16  199.204405  238.47  130.26  5.017750e+08
# 2017-07-23  215.779286  245.55  153.25  7.221637e+08
# 2017-07-30  205.110357  229.96  178.03  2.657305e+08
# ...                ...     ...     ...           ...
# 2020-02-16  257.255238  286.39  216.31  3.912867e+08
# 2020-02-23  267.263690  285.30  242.36  3.067838e+08
# 2020-03-01  238.697500  276.91  209.26  3.693920e+08
# 2020-03-08  231.284583  247.62  196.00  2.736569e+08
# 2020-03-15  179.979487  207.79   90.00  4.983998e+08
#
# [142 rows x 4 columns]

# %%
df=pd.read_csv('2019_stack_results.csv',index_col='Respondent')
df2=pd.read_csv('2019_survey_schema.csv')

# %%
filt=df['Country']=='India'
india_df=df[filt]

# %%
india_df.to_csv('modified_2019.csv')

# %%
india_df.to_csv('modified_2019.tsv',sep='\t')

# %%
india_df.to_excel('modified_2019.xlsx')

# %%
test=pd.read_excel('modified_2019.xlsx',index_col='Respondent')

# %%
test.head()
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 8              Less than once per year
# 10          Once a month or more often
# 15                               Never
# 50          Once a month or more often
# 65                               Never
#
#                                                    OpenSource  \
# Respondent
# 8           OSS is, on average, of HIGHER quality than pro...
# 10          OSS is, on average, of HIGHER quality than pro...
# 15          OSS is, on average, of HIGHER quality than pro...
# 50          OSS is, on average, of LOWER quality than prop...
# ...

# %%
india_df.to_json('modified_2019.json',orient='records',lines=True)

# %%
test=pd.read_json('modified_2019.json')
